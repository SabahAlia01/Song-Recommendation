# %% [markdown]
# **PROJECT DETAILS**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings ("ignore")

# %%
data=pd.read_csv("dataset (1).csv",index_col=0)

# %%
data.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
data.tail()
# Out:
#                       track_id           artists  \
# 113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# 113997       Miss Perfumado          22       271466     False         0.629
# 113998              Friends          41       283893     False         0.587
# 113999            Barbincor          22       241826     False         0.526
#
#         energy  key  loudness  mode  speechiness  acousticness  \
# 113995   0.235    5   -16.393     1       0.0422         0.640
# 113996   0.117    0   -18.318     0       0.0401         0.994
# 113997   0.329    0   -10.895     0       0.0420         0.867
# 113998   0.506    7   -10.889     1       0.0297         0.381
# 113999   0.487    1   -10.204     0       0.0725         0.681
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 113995             0.928    0.0863   0.0339  125.995               5
# 113996             0.976    0.1050   0.0350   85.239               4
# 113997             0.000    0.0839   0.7430  132.378               4
# 113998             0.000    0.2700   0.4130  135.960               4
# 113999             0.000    0.0893   0.7080   79.198               4
#
#         track_genre
# 113995  world-music
# 113996  world-music
# 113997  world-music
# 113998  world-music
# 113999  world-music

# %%
data.shape
# Out:
# (114000, 20)

# %%
data.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# 25%         2.000000     -10.013000       0.000000       0.035900
# 50%         5.000000      -7.004000       1.000000       0.048900
# 75%         8.000000      -5.003000       1.000000       0.084500
# max        11.000000       4.532000       1.000000       0.965000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  114000.000000     114000.000000  114000.000000  114000.000000
# mean        0.314910          0.156050       0.213553       0.474068
# std         0.332523          0.309555       0.190378       0.259261
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.016900          0.000000       0.098000       0.260000
# 50%         0.169000          0.000042       0.132000       0.464000
# 75%         0.598000          0.049000       0.273000       0.683000
# max         0.996000          1.000000       1.000000       0.995000
#
#                tempo  time_signature
# count  114000.000000   114000.000000
# mean      122.147837        3.904035
# std        29.978197        0.432621
# min         0.000000        0.000000
# 25%        99.218750        4.000000
# 50%       122.017000        4.000000
# 75%       140.071000        4.000000
# max       243.372000        5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
#  16  valence           114000 non-null  float64
#  17  tempo             114000 non-null  float64
#  18  time_signature    114000 non-null  int64
#  19  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(5), object(5)
# memory usage: 17.5+ MB

# %%
data.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
data=data.dropna()
data.isna().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 450

# %%
data=data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
data.shape
# Out:
# (113549, 20)

# %%
data.nunique()
# Out:
# track_id            89740
# artists             31437
# album_name          46589
# track_name          73608
# popularity            101
# duration_ms         50696
# explicit                2
# danceability         1174
# energy               2083
# key                    12
# loudness            19480
# mode                    2
# speechiness          1489
# acousticness         5061
# instrumentalness     5346
# liveness             1722
# valence              1790
# tempo               45652
# time_signature          5
# track_genre           114
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
#  16  valence           114000 non-null  float64
#  17  tempo             114000 non-null  float64
#  18  time_signature    114000 non-null  int64
#  19  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(5), object(5)
# memory usage: 16.6+ MB

# %%
data.popularity.min()
# Out:
# 0

# %%
data.popularity.max()
# Out:
# 100

# %% [markdown]
# #### Data Analysis (EDA)

# %% [raw]
# In EDA, we always compare with the dependent variable, here Popularity. So we see the relationships of different features with this variable.
#
# 1.Missing Values
# 2.Duplicate values
# 3.All the numerical variables
# 4.Distribution of the numerical variables: Check the skewness of the features.
# 5.Categorical variables
# 6.Cardinality of Categorical variables
# 7.Outliers
# 8.Relationship between independent and dependent features

# %% [markdown]
# #### Missing Values

# %%
features_with_nan=[feature for feature in data.columns if data[feature].isna().sum()>0]
features_with_nan
# Out:
# ['artists', 'album_name', 'track_name']

# %%
for feature in features_with_nan:
    print('Number of missing value in {}: {}'.format(feature,np.round(data[feature].isna().sum())))
# Out:
# Number of missing value in artists: 1
# Number of missing value in album_name: 1
# Number of missing value in track_name: 1

# %% [markdown]
# We see that the number of missing values is just 1 in each of the columns. So we can drop these nan values since the number is very less as compared to total number of entries

# %%
 data=data.dropna()

# %%
data.isna().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# #### Dropping the duplicates

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (113549, 20)

# %% [markdown]
# #### Numerical features

# %%
feature_numerical=[feature for feature in data.columns if data[feature].dtype!='O']
print('Number of numerical columns=', len(feature_numerical))
data[feature_numerical].head()
# Out:
# Number of numerical columns= 15
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0          73       230666     False         0.676  0.4610    1    -6.746
# 1          55       149610     False         0.420  0.1660    1   -17.235
# 2          57       210826     False         0.438  0.3590    0    -9.734
# 3          71       201933     False         0.266  0.0596    0   -18.515
# 4          82       198853     False         0.618  0.4430    2    -9.681
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.1430        0.0322          0.000001    0.3580    0.715
# 1     1       0.0763        0.9240          0.000006    0.1010    0.267
# 2     1       0.0557        0.2100          0.000000    0.1170    0.120
# 3     1       0.0363        0.9050          0.000071    0.1320    0.143
# 4     1       0.0526        0.4690          0.000000    0.0829    0.167
#
#      tempo  time_signature
# 0   87.917               4
# 1   77.489               4
# 2   76.332               4
# 3  181.740               3
# 4  119.949               4

# %% [markdown]
# Selecting out the discrete features among the numerical features and finding their relationship with popularity

# %%
feature_discrete_numerical=[feature for feature in feature_numerical if data[feature].nunique()<50]
feature_discrete_numerical
# Out:
# ['explicit', 'key', 'mode', 'time_signature']

# %%
for feature in feature_discrete_numerical:
    dataset=data.copy()
    sns.barplot(x=feature, y=dataset['popularity'], data=dataset, estimator=np.median)
    plt.show()

# %% [markdown]
# Observation:
#
# 1.We see that songs which contain explicit lyrics are more popular in comparision with sons that do not contain such lyrics.
# 2.The popularity of songs or tracks in different keys do not affect theirpopularity much. Songs in all the keys are almost equally popular.
# 3.The tracks in both the modes are equally popular, the major as well as the minor.
# 4.The time signature (meter) is a notational convention to specify how many beats are in each bar. The time_signature should lie between 3 to 7 as per the data dictionary time signatures of 3/4, to 7/4. But here time_signature ranges from 0 to 5. We would probably convert these in Feature Selection. From the current looks, tracks having time_signature 0 and 4 are more popular than other.

# %% [markdown]
# ###### Selecting the continuous features among the numerical features and finding their distribution

# %%
features_continuous_numerical=[features for features in feature_numerical if features not in feature_discrete_numerical]

# %%
features_continuous_numerical
# Out:
# ['popularity',
#  'duration_ms',
#  'danceability',
#  'energy',
#  'loudness',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo']

# %%
from scipy.stats import skew

# %%
for feature in features_continuous_numerical:
    dataset=data.copy()
    print(feature, 'skewness is :', skew(dataset[feature]))
    sns.histplot(x=feature, data=dataset, bins=25, kde=True)
    plt.show()
# Out:
# popularity skewness is : 0.04222809948109981
# duration_ms skewness is : 10.814434004933338
# danceability skewness is : -0.4003991295600715
# energy skewness is : -0.598542182428158
# loudness skewness is : -2.0133133823721505
# speechiness skewness is : 4.644508700286168
# acousticness skewness is : 0.7302103030827026
# instrumentalness skewness is : 1.7377466866935405
# liveness skewness is : 2.1054497237799685
# valence skewness is : 0.11477275798096229
# tempo skewness is : 0.23160111991386964

# %% [raw]
# Observation:
#
# 1.We see that danceability, valence and tempo are almost normal distribution.
# 2.Loudness is left skewed.
# 3.Rest all are right skewed.
#
#
# Now to remove the skewness, we can perform operations like log transformation, square-root transformation etc. But before applying any of the methods, lets check the correlation of the continuous features with the target.

# %%
dataset=data.copy()
plt.figure(figsize=(10,6))
sns.heatmap(data[features_continuous_numerical].corr(), annot=True)
plt.show()

# %% [markdown]
# We see that none of the continuous features has a great correlation with the target variable popularity. So we can perform the transformations if we opt for regresion model. The other models like SVM, Tree based methods, XG boost do not require such transformations. We would deal with the transformations in feature engineering.

# %%
# checking the outliers
for feature in features_continuous_numerical:
    dataset=data.copy()
    sns.boxplot(data=dataset[feature])
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# We see that apart from energy, acousticness and valence, there are a lot of outliers in most of the features.

# %%
feature_categorical=[feature for feature in data.columns if data[feature].dtypes=='O']
print('Number of categorical features:', len(feature_categorical))
data[feature_categorical].head()
# Out:
# Number of categorical features: 5
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name track_genre
# 0                      Comedy    acoustic
# 1            Ghost - Acoustic    acoustic
# 2              To Begin Again    acoustic
# 3  Can't Help Falling In Love    acoustic
# 4                     Hold On    acoustic

# %%
feature_categorical
# Out:
# ['track_id', 'artists', 'album_name', 'track_name', 'track_genre']

# %% [markdown]
# Among the categorical features, track_id would be unique for each entry. Later we can drop this column. Lets check the cardinality of the categorical features to know the number of unique variables.

# %%
for feature in feature_categorical:
    dataset=data.copy()
    print(feature, ': Number of unique entries:', dataset[feature].nunique())
# Out:
# track_id : Number of unique entries: 89740
# artists : Number of unique entries: 31437
# album_name : Number of unique entries: 46589
# track_name : Number of unique entries: 73608
# track_genre : Number of unique entries: 114

# %% [markdown]
# Observation: There are a lot of unique entries in each of the categorical features

# %% [markdown]
# Most of the categorical features are names like track name, album name, artist name, etc. track_id is unique for every song/track. We can later drop this. track_genre can have effect in popularity.

# %%
dataset=data.copy()
plt.figure(figsize=(16,12))
sns.lineplot(x='track_genre', y='popularity', data=dataset)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Machine Learning Models

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
data=remove_outliers(data,"duration_ms")
data[["duration_ms"]].boxplot()
# Out:
# <Axes: >

# %%
data=remove_outliers(data,"loudness")
data[["loudness"]].boxplot()
# Out:
# <Axes: >

# %%
data=remove_outliers(data,"speechiness")
data[["speechiness"]].boxplot()
# Out:
# <Axes: >

# %%
data=remove_outliers(data,"liveness")
data[["liveness"]].boxplot()
# Out:
# <Axes: >

# %%
data=remove_outliers(data,"tempo")
data[["tempo"]].boxplot()
# Out:
# <Axes: >

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data_reduce['features'] = data_reduce['track_genre'] + ' ' + data_reduce['artists'] + ' ' + data_reduce['track_name']

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data_reduce['features'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
vectors=cv.fit_transform(new_df['features']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# TFID WITH NearestKneighbors

# %%
data_d_index = data_d.reset_index(drop=True)
data_d_index.index = data_d_index.index + 1

# %%
data_d_index
# Out:
#                       track_id                 artists  \
# 1       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 2       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 3       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 4       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 5       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113545  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113546  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113547  6x8ZfSoqDjuNa5SVP5QjvX          CesÃ¡ria Evora
# 113548  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113549  2hETkH7cOfqmz3LqZDHZf5          CesÃ¡ria Evora
#
#                                                album_name  \
# 1                                                  Comedy
# 2                                        Ghost (Acoustic)
# 3                                          To Begin Again
# 4       Crazy Rich Asians (Original Motion Picture Sou...
# 5                                                 Hold On
# ...                                                   ...
# 113545  #mindfulness - Soft Rain for Mindful Meditatio...
# 113546  #mindfulness - Soft Rain for Mindful Meditatio...
# 113547                                            Best Of
# 113548                                  Change Your World
# 113549                                     Miss Perfumado
#
#                         track_name  popularity  duration_ms  explicit  \
# 1                           Comedy          73       230666     False
# 2                 Ghost - Acoustic          55       149610     False
# 3                   To Begin Again          57       210826     False
# 4       Can't Help Falling In Love          71       201933     False
# 5                          Hold On          82       198853     False
# ...                            ...         ...          ...       ...
# 113545         Sleep My Little Boy          21       384999     False
# 113546            Water Into Light          22       385000     False
# 113547              Miss Perfumado          22       271466     False
# 113548                     Friends          41       283893     False
# 113549                   Barbincor          22       241826     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 2              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 3              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 4              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 5              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113545         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113546         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113547         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113548         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113549         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 1               0.000001    0.3580   0.7150   87.917               4
# 2               0.000006    0.1010   0.2670   77.489               4
# 3               0.000000    0.1170   0.1200   76.332               4
# 4               0.000071    0.1320   0.1430  181.740               3
# 5               0.000000    0.0829   0.1670  119.949               4
# ...                  ...       ...      ...      ...             ...
# 113545          0.928000    0.0863   0.0339  125.995               5
# 113546          0.976000    0.1050   0.0350   85.239               4
# 113547          0.000000    0.0839   0.7430  132.378               4
# 113548          0.000000    0.2700   0.4130  135.960               4
# 113549          0.000000    0.0893   0.7080   79.198               4
#
#         track_genre
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
# 5          acoustic
# ...             ...
# 113545  world-music
# 113546  world-music
# 113547  world-music
# 113548  world-music
# 113549  world-music
#
# [113549 rows x 20 columns]

# %%
data_reduce=data_d_index[['artists','album_name','track_name','track_genre']]

# %%
data_reduce['features']=data_reduce['artists']+' '+data_reduce['album_name']+' '+data_reduce['track_name']+' '+data_reduce['track_genre']

# %%
data_reduce
# Out:
#                        artists  \
# 1                  Gen Hoshino
# 2                 Ben Woodward
# 3       Ingrid Michaelson;ZAYN
# 4                 Kina Grannis
# 5             Chord Overstreet
# ...                        ...
# 113545           Rainy Lullaby
# 113546           Rainy Lullaby
# 113547          CesÃ¡ria Evora
# 113548        Michael W. Smith
# 113549          CesÃ¡ria Evora
#
#                                                album_name  \
# 1                                                  Comedy
# 2                                        Ghost (Acoustic)
# 3                                          To Begin Again
# 4       Crazy Rich Asians (Original Motion Picture Sou...
# 5                                                 Hold On
# ...                                                   ...
# 113545  #mindfulness - Soft Rain for Mindful Meditatio...
# 113546  #mindfulness - Soft Rain for Mindful Meditatio...
# 113547                                            Best Of
# 113548                                  Change Your World
# 113549                                     Miss Perfumado
#
#                         track_name  track_genre  \
# 1                           Comedy     acoustic
# 2                 Ghost - Acoustic     acoustic
# 3                   To Begin Again     acoustic
# 4       Can't Help Falling In Love     acoustic
# 5                          Hold On     acoustic
# ...                            ...          ...
# 113545         Sleep My Little Boy  world-music
# 113546            Water Into Light  world-music
# 113547              Miss Perfumado  world-music
# 113548                     Friends  world-music
# 113549                   Barbincor  world-music
#
#                                                  features
# 1                      Gen Hoshino Comedy Comedy acoustic
# 2       Ben Woodward Ghost (Acoustic) Ghost - Acoustic...
# 3       Ingrid Michaelson;ZAYN To Begin Again To Begin...
# 4       Kina Grannis Crazy Rich Asians (Original Motio...
# 5               Chord Overstreet Hold On Hold On acoustic
# ...                                                   ...
# 113545  Rainy Lullaby #mindfulness - Soft Rain for Min...
# 113546  Rainy Lullaby #mindfulness - Soft Rain for Min...
# 113547  CesÃ¡ria Evora Best Of Miss Perfumado world-music
# 113548  Michael W. Smith Change Your World Friends wor...
# 113549  CesÃ¡ria Evora Miss Perfumado Barbincor world-...
#
# [113549 rows x 5 columns]

# %%
data_reduce['features']=data_reduce['features'].apply(lambda x:x.lower())
data_reduce['artists']=data_reduce['artists'].apply(lambda x: x.replace(';',' '))

# %%
data_reduce
# Out:
#                        artists  \
# 1                  Gen Hoshino
# 2                 Ben Woodward
# 3       Ingrid Michaelson ZAYN
# 4                 Kina Grannis
# 5             Chord Overstreet
# ...                        ...
# 113545           Rainy Lullaby
# 113546           Rainy Lullaby
# 113547          CesÃ¡ria Evora
# 113548        Michael W. Smith
# 113549          CesÃ¡ria Evora
#
#                                                album_name  \
# 1                                                  Comedy
# 2                                        Ghost (Acoustic)
# 3                                          To Begin Again
# 4       Crazy Rich Asians (Original Motion Picture Sou...
# 5                                                 Hold On
# ...                                                   ...
# 113545  #mindfulness - Soft Rain for Mindful Meditatio...
# 113546  #mindfulness - Soft Rain for Mindful Meditatio...
# 113547                                            Best Of
# 113548                                  Change Your World
# 113549                                     Miss Perfumado
#
#                         track_name  track_genre  \
# 1                           Comedy     acoustic
# 2                 Ghost - Acoustic     acoustic
# 3                   To Begin Again     acoustic
# 4       Can't Help Falling In Love     acoustic
# 5                          Hold On     acoustic
# ...                            ...          ...
# 113545         Sleep My Little Boy  world-music
# 113546            Water Into Light  world-music
# 113547              Miss Perfumado  world-music
# 113548                     Friends  world-music
# 113549                   Barbincor  world-music
#
#                                                  features
# 1                      gen hoshino comedy comedy acoustic
# 2       ben woodward ghost (acoustic) ghost - acoustic...
# 3       ingrid michaelson;zayn to begin again to begin...
# 4       kina grannis crazy rich asians (original motio...
# 5               chord overstreet hold on hold on acoustic
# ...                                                   ...
# 113545  rainy lullaby #mindfulness - soft rain for min...
# 113546  rainy lullaby #mindfulness - soft rain for min...
# 113547  cesã¡ria evora best of miss perfumado world-music
# 113548  michael w. smith change your world friends wor...
# 113549  cesã¡ria evora miss perfumado barbincor world-...
#
# [113549 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(data_reduce['features'])

# %%
from sklearn.neighbors import NearestNeighbors

# %%
nn_model = NearestNeighbors(metric='cosine', algorithm='brute')

# %%
def recom(input_value):
    # Determine the column to filter based on the input
    filter_columns = ["artists", "track_name", "album_name","track_genre"]

    tfidf_matrix = tfidf_vectorizer.fit_transform(data_reduce['features'])

    nn_model.fit(tfidf_matrix)

    for filter_column in filter_columns:
        filtered_data = data_reduce[data_reduce[filter_column] == input_value]
        if not filtered_data.empty:
            # Get the index of the first entry for the given input
            input_index = filtered_data.index[0]

            # Use Nearest Neighbors to find similar songs
            _, indices = nn_model.kneighbors(tfidf_matrix[input_index], n_neighbors=20)

            # Exclude the input song itself
            indices = indices.flatten()[1:]

            # Create a set to keep track of unique track names
            unique_track_names = set()

            # Print the recommended unique track names
            for index in indices:
                current_track_name = data_reduce.iloc[index]['track_name']
                if current_track_name not in unique_track_names:
                    print(current_track_name)
                    unique_track_names.add(current_track_name)
            return

# %%
recom("The Supremes") #recommend using artists as input
# Out:
# Frankie (Edit Version)
# We're Not Gonna Take It (Single Version)
# He's the Greatest Dancer - 1995 Remaster

# %%
recom('Till We Meet Again')
# Out:
# Fossegrim - BBC Sessions 2010
# Utrydd Dei Svake
# Undertro
# Svartmesse
# Nekrokosmos
# Snilepisk
# Bronsegud
# Delirium tremens
# Spring Fra Livet

# %%
recom('Hold On')
# Out:
# Days I Will Remember
# Remember These Days
# Remember To Remember Me
# I Remember
# Remember

# %%
recom('disco')
# Out:
# Lady - Hear Me Tonight
# Can You Hear Me
# Hear Me Out
# Tonight
# Save Me Tonight
# Do You Hear What I Hear?
# Take Me Tonight
# Who You Are To Me (feat. Lady A)

# %%
recom('A Very 60s Christmas')
# Out:
# Rudolph The Red-Nosed Reindeer

# %%
recom('acoustic')
# Out:
# Ghost - Acoustic
# Memories (Acoustic)
# When the Party's over (Acoustic Piano)
# Call You Mine (Acoustic Piano)
# Rockabye - Acoustic Version
# Umbrella - Acoustic Version
# Golden Hour - Acoustic Piano
# Don't Wanna Know - Acoustic Version
